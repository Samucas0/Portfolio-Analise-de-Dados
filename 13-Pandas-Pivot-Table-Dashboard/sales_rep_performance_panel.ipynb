# %% [markdown]
# # Day 13: Sales Performance Dashboard 📊
#
# **Objective:** Build a quick matrix to identify top sales reps and category specialists.
# **Tech:** Pandas `pivot_table` for reshaping and Styler for the UI.
#
# ---
#
# ## 1. Data Setup
# Simulating a transaction log since I don't have a live DB connection here.
# Generating 1,500 rows with a Pareto-like distribution (few large sales, many small ones).

# %%
import pandas as pd
import numpy as np

# Setting seed so numbers don't change every time I run this
np.random.seed(42)

# Config
n_transactions = 1500
sales_reps = ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank']
categories = ['Software', 'Consulting', 'Hardware', 'Maintenance']

# Simulating the Data
df_sales = pd.DataFrame({
    'Transaction_ID': range(1, n_transactions + 1),
    'Date': pd.date_range(start='2024-01-01', periods=n_transactions, freq='h'),
    'Sales_Rep': np.random.choice(sales_reps, n_transactions),
    'Category': np.random.choice(categories, n_transactions),
    # Using exponential distribution to mimic real sales (lots of small deals, few whales)
    'Amount': np.round(np.random.exponential(scale=1000, size=n_transactions) + 100, 2)
})

print(f"Data generated. Rows: {df_sales.shape[0]}")
df_sales.head()
# Out:
# Data generated. Rows: 1500
#    Transaction_ID                Date Sales_Rep     Category   Amount
# 0               1 2024-01-01 00:00:00     David   Consulting  3419.31
# 1               2 2024-01-01 01:00:00       Eva   Consulting   385.79
# 2               3 2024-01-01 02:00:00   Charlie  Maintenance   243.64
# 3               4 2024-01-01 03:00:00       Eva     Hardware   642.28
# 4               5 2024-01-01 04:00:00       Eva     Software  1662.26

# %% [markdown]
# ## 2. Aggregating Data (The Heavy Lifting)
# Using `pivot_table` instead of `groupby` because I need a matrix view (Reps x Categories).
# This makes it easier for stakeholders to compare performance side-by-side.

# %%
# Creating the matrix
# Rows: Reps | Cols: Categories | Values: Sum of Sales
performance_matrix = df_sales.pivot_table(
    values='Amount',
    index='Sales_Rep',
    columns='Category',
    aggfunc='sum',
    fill_value=0 # Important: If a rep sold nothing in a category, put 0, not NaN
)

# Adding a 'Total' column to sort by best overall performer later
performance_matrix['Total_Revenue'] = performance_matrix.sum(axis=1)

# Sorting so the best reps are at the top
performance_matrix = performance_matrix.sort_values(by='Total_Revenue', ascending=False)

# Quick sanity check
display(performance_matrix)
# Out:
# Category   Consulting  Hardware  Maintenance  Software  Total_Revenue
# Sales_Rep
# Alice        68339.54  61345.92    101702.82  66076.80      297465.08
# Bob          91590.13  52881.37     75326.18  57628.91      277426.59
# Frank        65057.81  69797.20     58885.36  82859.25      276599.62
# Charlie      83613.26  60300.62     64419.77  67444.85      275778.50
# Eva          78619.16  54982.72     77357.44  62635.92      273595.24
# David        62193.63  55132.48     57065.91  94759.18      269151.20

# %% [markdown]
# ## 3. Dashboard Styling
# Raw numbers are hard to scan.
# Adding a heatmap to highlight category specialists and data bars for total revenue.

# %%
# Formatting config
currency_fmt = "${:,.2f}"

# Applying the style
dashboard = (performance_matrix.style
    .format(currency_fmt)                                   # Currency format
    .background_gradient(cmap='Greens', subset=categories)  # Darker green = Higher sales in that category
    .bar(subset=['Total_Revenue'], color='#d65f5f')         # Bar chart for the total column
    .set_caption("FY2024 Sales Performance Matrix")
)

display(dashboard)
# Out:
# <style type="text/css">
# #T_750b3_row0_col0 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_750b3_row0_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_750b3_row0_col2, #T_750b3_row1_col0, #T_750b3_row2_col1, #T_750b3_row5_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_750b3_row0_col3 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_750b3_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_750b3_row1_col1, #T_750b3_row1_col3, #T_750b3_row5_col0, #T_750b3_row5_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_750b3_row1_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_750b3_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.3%, transparent 93.3%);
# }
# #T_750b3_row2_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_750b3_row2_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_750b3_row2_col3 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_750b3_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.0%, transparent 93.0%);
# }
# #T_750b3_row3_col0 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_750b3_row3_col1 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_750b3_row3_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_750b3_row3_col3 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_750b3_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.7%, transparent 92.7%);
# }
# #T_750b3_row4_col0 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_750b3_row4_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_750b3_row4_col2 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_750b3_row4_col3, #T_750b3_row5_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_750b3_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.0%, transparent 92.0%);
# }
# #T_750b3_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.5%, transparent 90.5%);
# }
# </style>
# <table id="T_750b3">
#   <caption>FY2024 Sales Performance Matrix</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Category</th>
#       <th id="T_750b3_level0_col0" class="col_heading level0 col0" >Consulting</th>
#       <th id="T_750b3_level0_col1" class="col_heading level0 col1" >Hardware</th>
#       <th id="T_750b3_level0_col2" class="col_heading level0 col2" >Maintenance</th>
#       <th id="T_750b3_level0_col3" class="col_heading level0 col3" >Software</th>
#       <th id="T_750b3_level0_col4" class="col_heading level0 col4" >Total_Revenue</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sales_Rep</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_750b3_level0_row0" class="row_heading level0 row0" >Alice</th>
#       <td id="T_750b3_row0_col0" class="data row0 col0" >$68,339.54</td>
#       <td id="T_750b3_row0_col1" class="data row0 col1" >$61,345.92</td>
#       <td id="T_750b3_row0_col2" class="data row0 col2" >$101,702.82</td>
#       <td id="T_750b3_row0_col3" class="data row0 col3" >$66,076.80</td>
#       <td id="T_750b3_row0_col4" class="data row0 col4" >$297,465.08</td>
#     </tr>
#     <tr>
#       <th id="T_750b3_level0_row1" class="row_heading level0 row1" >Bob</th>
#       <td id="T_750b3_row1_col0" class="data row1 col0" >$91,590.13</td>
#       <td id="T_750b3_row1_col1" class="data row1 col1" >$52,881.37</td>
#       <td id="T_750b3_row1_col2" class="data row1 col2" >$75,326.18</td>
#       <td id="T_750b3_row1_col3" class="data row1 col3" >$57,628.91</td>
#       <td id="T_750b3_row1_col4" class="data row1 col4" >$277,426.59</td>
#     </tr>
#     <tr>
#       <th id="T_750b3_level0_row2" class="row_heading level0 row2" >Frank</th>
#       <td id="T_750b3_row2_col0" class="data row2 col0" >$65,057.81</td>
#       <td id="T_750b3_row2_col1" class="data row2 col1" >$69,797.20</td>
#       <td id="T_750b3_row2_col2" class="data row2 col2" >$58,885.36</td>
#       <td id="T_750b3_row2_col3" class="data row2 col3" >$82,859.25</td>
#       <td id="T_750b3_row2_col4" class="data row2 col4" >$276,599.62</td>
#     </tr>
#     <tr>
#       <th id="T_750b3_level0_row3" class="row_heading level0 row3" >Charlie</th>
#       <td id="T_750b3_row3_col0" class="data row3 col0" >$83,613.26</td>
#       <td id="T_750b3_row3_col1" class="data row3 col1" >$60,300.62</td>
#       <td id="T_750b3_row3_col2" class="data row3 col2" >$64,419.77</td>
#       <td id="T_750b3_row3_col3" class="data row3 col3" >$67,444.85</td>
#       <td id="T_750b3_row3_col4" class="data row3 col4" >$275,778.50</td>
#     </tr>
#     <tr>
#       <th id="T_750b3_level0_row4" class="row_heading level0 row4" >Eva</th>
#       <td id="T_750b3_row4_col0" class="data row4 col0" >$78,619.16</td>
#       <td id="T_750b3_row4_col1" class="data row4 col1" >$54,982.72</td>
#       <td id="T_750b3_row4_col2" class="data row4 col2" >$77,357.44</td>
#       <td id="T_750b3_row4_col3" class="data row4 col3" >$62,635.92</td>
#       <td id="T_750b3_row4_col4" class="data row4 col4" >$273,595.24</td>
#     </tr>
#     <tr>
#       <th id="T_750b3_level0_row5" class="row_heading level0 row5" >David</th>
#       <td id="T_750b3_row5_col0" class="data row5 col0" >$62,193.63</td>
#       <td id="T_750b3_row5_col1" class="data row5 col1" >$55,132.48</td>
#       <td id="T_750b3_row5_col2" class="data row5 col2" >$57,065.91</td>
#       <td id="T_750b3_row5_col3" class="data row5 col3" >$94,759.18</td>
#       <td id="T_750b3_row5_col4" class="data row5 col4" >$269,151.20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Key Findings
#
# 1.  **Top Performer:** Check the `Total_Revenue` column. The longest bar indicates the MVP.
# 2.  **Specialization:** Look at the heatmap.
#     * Some reps might be "Hardware" heavy but weak in "Consulting".
#     * This helps in assigning the right leads to the right person.
